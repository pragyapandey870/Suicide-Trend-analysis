# %% [markdown]
# PS - You need to have the CSV file uploaded in the jupyter notebook. Here is the link to the dataset - https://www.kaggle.com/datasets/data855/sucidedata

# %% [markdown]
# ## SUICIDE TREND OVER THE YEARS

# %% [markdown]
# This project contains the data record of suicides trends of most of the countries.
# The aim of the project is to analyze the condition of suicide in diffrent parts of the world

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
df=pd.read_csv("SucideData.csv")

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year   gdp_for_year  \
# 0               6.71  Albania1987           NaN  2,156,624,900
# 1               5.19  Albania1987           NaN  2,156,624,900
# 2               4.83  Albania1987           NaN  2,156,624,900
# 3               4.59  Albania1987           NaN  2,156,624,900
# 4               3.28  Albania1987           NaN  2,156,624,900
#
#    gdp_per_capita       generation
# 0             796     Generation X
# 1             796           Silent
# 2             796     Generation X
# 3             796  G.I. Generation
# ...

# %% [markdown]
# # Data preparation and cleaning

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year    gdp_for_year  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year    gdp_for_year  \
# ...

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita
# count   8364.000000    27820.000000
# mean       0.776601    16866.464414
# std        0.093367    18887.576472
# min        0.483000      251.000000
# 25%        0.713000     3447.000000
# 50%        0.779000     9372.000000
# 75%        0.855000    24874.000000
# max        0.944000   126352.000000

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year', ' gdp_for_year',
#        'gdp_per_capita', 'generation'],
#       dtype='object')

# %%
df.shape
# Out:
# (27820, 12)

# %%
df.year.unique()
# Out:
# array([1987, 1988, 1989, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        1985, 1986, 1990, 1991, 2012, 2013, 2014, 2015, 2011, 2016])

# %% [markdown]
#  Lets the find out the total number of "Unique "countires in the data set

# %%
df.country.unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %% [markdown]
# Let's check is there is any null value

# %%
df.isna().sum()
# Out:
# country                  0
# year                     0
# sex                      0
# age                      0
# suicides_no              0
# population               0
# suicides/100k pop        0
# country-year             0
# HDI for year         19456
#  gdp_for_year            0
# gdp_per_capita           0
# generation               0
# dtype: int64

# %% [markdown]
# So, out of 27820 "HDI for year" column has 19456 null values .
#    HDI is Human Development Index Value

# %%
df["HDI for year"]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 27815    0.675
# 27816    0.675
# 27817    0.675
# 27818    0.675
# 27819    0.675
# Name: HDI for year, Length: 27820, dtype: float64

# %%
df["HDI for year"].count()
# Out:
# 8364

# %% [markdown]
# "HDi for year " has total 8364 values

# %% [markdown]
#  Lets delete  the "HDI for year " column

# %%
del df["HDI for year"]

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        gdp_per_capita
# count    27820.000000
# mean     16866.464414
# std      18887.576472
# min        251.000000
# 25%       3447.000000
# 50%       9372.000000
# 75%      24874.000000
# max     126352.000000

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year   gdp_for_year  gdp_per_capita  \
# 0               6.71  Albania1987  2,156,624,900             796
# 1               5.19  Albania1987  2,156,624,900             796
# 2               4.83  Albania1987  2,156,624,900             796
# 3               4.59  Albania1987  2,156,624,900             796
# 4               3.28  Albania1987  2,156,624,900             796
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %% [markdown]
# # Now let's start with analysing the data

# %%
country_df=df.groupby('country')['suicides_no'].mean()

# %%
country_df
# Out:
# country
# Albania                    7.462121
# Antigua and Barbuda        0.033951
# Argentina                221.018817
# Armenia                    6.392617
# Aruba                      0.601190
#                            ...
# United Arab Emirates       8.638889
# United Kingdom           367.755376
# United States           2779.604839
# Uruguay                   39.101190
# Uzbekistan               131.829545
# Name: suicides_no, Length: 101, dtype: float64

# %%
country_df.plot();

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year   gdp_for_year  gdp_per_capita  \
# 0               6.71  Albania1987  2,156,624,900             796
# 1               5.19  Albania1987  2,156,624,900             796
# 2               4.83  Albania1987  2,156,624,900             796
# 3               4.59  Albania1987  2,156,624,900             796
# 4               3.28  Albania1987  2,156,624,900             796
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %%
df.sex
# Out:
# 0          male
# 1          male
# 2        female
# 3          male
# 4          male
#           ...
# 27815    female
# 27816    female
# 27817      male
# 27818    female
# 27819    female
# Name: sex, Length: 27820, dtype: object

# %% [markdown]
# Let's analyze the suicide scenario of Albania

# %%
df.set_index('country',inplace=True)

# %%
df2=df.loc['Albania']
df2
# Out:
#          year     sex          age  suicides_no  population  \
# country
# Albania  1987    male  15-24 years           21      312900
# Albania  1987    male  35-54 years           16      308000
# Albania  1987  female  15-24 years           14      289700
# Albania  1987    male    75+ years            1       21800
# Albania  1987    male  25-34 years            9      274300
# ...       ...     ...          ...          ...         ...
# Albania  2010  female  35-54 years           12      394593
# Albania  2010  female  55-74 years            7      241491
# Albania  2010  female  15-24 years            6      263581
# Albania  2010  female   5-14 years            2      223969
# Albania  2010    male   5-14 years            0      240939
#
#          suicides/100k pop country-year    gdp_for_year  gdp_per_capita  \
# country
# Albania               6.71  Albania1987   2,156,624,900             796
# Albania               5.19  Albania1987   2,156,624,900             796
# ...

# %%
plt.title("Suicides in Albania")
sns.barplot(x=df2.age,y=df2.suicides_no,hue=df2.sex);

# %%
df2.suicides_no.sum()
# Out:
# 1970

# %%
df2.population.mean()
# Out:
# 236081.3143939394

# %% [markdown]
# # * In Albania from 1987 to 2010 the total no suicides is 1970  with mean population of 236081

# %% [markdown]
# Let's see the global suicide trend with respect ot gender

# %%
sns.barplot(x=df.age,y=df.suicides_no,hue=df.sex);

# %% [markdown]
# Plotting a line plot for suicide numbers over the year

# %%
plt.plot(df.year,df.suicides_no);

# %% [markdown]
# Let's plot a scatterplot to find out how different countries have different suicide number over the years

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15, 10)
sns.scatterplot(x=df.year,y=df.suicides_no,hue=df.index);

# %% [markdown]
# Looking at the plot ,it seems like some country from Romania to Serbia(in data set) have quite high suicide numbers over the years.
# Let's find out which country.

# %%
df_romania_to_Serbia=df.loc['Romania': 'Serbia']

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15,10)
sns.barplot(x=df_romania_to_Serbia.index,y=df_romania_to_Serbia.suicides_no);

# %% [markdown]
# Looking at the graph it seems like Russia have quite high suicide numbers

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15,10)
sns.barplot(x=df_romania_to_Serbia.index,y=df_romania_to_Serbia.suicides_no,hue=df3.sex);

# %% [markdown]
# Lets analyze the suicide trends of Russia

# %%
df_russia=df.loc['Russian Federation']

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15,10)
sns.barplot(x=df_russia.age,y=df_russia.suicides_no,hue=df_russia.sex);

# %% [markdown]
# It looks like Russian men from age-group 35-54 are more inclined towards suicidal thoughts

# %% [markdown]
# Plotting a barplot to find the suicide number over the years

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15, 13)
sns.barplot(x=df.year,y=df.suicides_no);

# %% [markdown]
# From the graph it looks like suicide numbers in the year 2016 have decreased but actually we don't have enough data for the year 2016.

# %%
df.head()
# Out:
#          year     sex          age  suicides_no  population  \
# country
# Albania  2016    male  15-24 years           21      312900
# Albania  2016    male  35-54 years           16      308000
# Albania  2016  female  15-24 years           14      289700
# Albania  2016    male    75+ years            1       21800
# Albania  2016    male  25-34 years            9      274300
#
#          suicides/100k pop country-year   gdp_for_year  gdp_per_capita  \
# country
# Albania               6.71  Albania1987  2,156,624,900             796
# Albania               5.19  Albania1987  2,156,624,900             796
# Albania               4.83  Albania1987  2,156,624,900             796
# Albania               4.59  Albania1987  2,156,624,900             796
# Albania               3.28  Albania1987  2,156,624,900             796
#
#               generation
# country
# Albania     Generation X
# Albania           Silent
# Albania     Generation X
# Albania  G.I. Generation
# ...

# %%
plt.plot(df_russia.suicides_no,df_russia.year);

# %% [markdown]
# Plotting a scatterplot to find if there any relation exist between gdp per capita and suicide numbers.

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(13, 11)
sns.scatterplot(x=df.gdp_per_capita,y=df.suicides_no,hue=df.year);

# %% [markdown]
# From graph it looks like Countries with high gdp per capita have low suicide numbers.

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(13, 11)
sns.scatterplot(x=df.gdp_per_capita,y=df.year,hue=df.index);

# %% [markdown]
# While Republic of korea and japan are countries with quite high suicide rates
# Let's analyze these countries

# %%
df_korea=df.loc['Republic of Korea']

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15,10)
sns.barplot(x=df_korea.age,y=df_korea.suicides_no,hue=df_korea.sex);

# %%
df_korea.suicides_no.sum()
# Out:
# 261730

# %%
df_russia.suicides_no.sum()
# Out:
# 1209742

# %%
df_japan=df.loc['Japan']
df_japan.suicides_no.sum()
# Out:
# 806902

# %%
df.head()
# Out:
#          year     sex          age  suicides_no  population  \
# country
# Albania  1987    male  15-24 years           21      312900
# Albania  1987    male  35-54 years           16      308000
# Albania  1987  female  15-24 years           14      289700
# Albania  1987    male    75+ years            1       21800
# Albania  1987    male  25-34 years            9      274300
#
#          suicides/100k pop country-year   gdp_for_year  gdp_per_capita  \
# country
# Albania               6.71  Albania1987  2,156,624,900             796
# Albania               5.19  Albania1987  2,156,624,900             796
# Albania               4.83  Albania1987  2,156,624,900             796
# Albania               4.59  Albania1987  2,156,624,900             796
# Albania               3.28  Albania1987  2,156,624,900             796
#
#               generation
# country
# Albania     Generation X
# Albania           Silent
# Albania     Generation X
# Albania  G.I. Generation
# ...

# %% [markdown]
# Let's Analyze suicides per 100k population for all countries

# %% [markdown]
# # Asking and answering questions

# %% [markdown]
# ## Q) List top 5 countries with high suicide rates

# %%
df_new1=df.loc["Albania":"Chile"]

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15,10)
sns.barplot(x=df_new1.index,y=df_new1['suicides/100k pop']);

# %%
df_new2=df.loc["Colombia":"Guyana"]

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15,10)
sns.barplot(x=df_new2.index,y=df_new2['suicides/100k pop']);

# %%
df_new3=df.loc["Hungary":"Mexico"]
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15,10)
sns.barplot(x=df_new3.index,y=df_new3['suicides/100k pop']);

# %%
df_new4=df.loc["Mongolia":"Seychelles"]
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(25,10)
sns.barplot(x=df_new4.index,y=df_new4['suicides/100k pop']);

# %%
df_new5=df.loc["Singapore":"Uzbekistan"]
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(20,10)
sns.barplot(x=df_new5.index,y=df_new5['suicides/100k pop']);

# %% [markdown]
# So the countries with hightest suicides per 100k populations are Belarus,Lithunia,Hungry,Russia and Sri Lanka

# %% [markdown]
# # Q) Which age group is committing more suicides

# %%
sns.scatterplot(x=df.age,y=df.suicides_no)
# Out:
# <AxesSubplot:xlabel='age', ylabel='suicides_no'>

# %% [markdown]
# People belonging to age group 35-54 are committing more suicides.

# %% [markdown]
# # Q) Which gender is committing more suicides

# %%
sns.barplot(x=df.sex,y=df.suicides_no);

# %% [markdown]
# # Q) Which generation is committing more Suicides.

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15, 13)
sns.barplot(x=df.generation,y=df.suicides_no);
